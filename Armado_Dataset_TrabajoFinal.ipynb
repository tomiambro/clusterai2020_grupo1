# %%
# importamos las librerías necesarias para trabajar.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Otros 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Descargar dataset crudo de:
#
# https://datos.gob.ar/dataset/salud-covid-19-casos-registrados-republica-argentina

# %%
#abro los datasets
completo = pd.read_csv("./data/Covid19Casos.csv", delimiter=',', parse_dates=['fecha_apertura','fecha_diagnostico','fecha_cui_intensivo','fecha_internacion','fecha_fallecimiento'])   
completo.head()
# Out:
#    id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0         1000000    M  53.0            Años              Argentina
# 1         1000002    M  21.0            Años              Argentina
# 2         1000003    F  40.0            Años              Argentina
# 3         1000005    F  58.0            Años              Argentina
# 4         1000006    M  28.0            Años              Argentina
#
#   residencia_provincia_nombre residencia_departamento_nombre  \
# 0                        CABA                SIN ESPECIFICAR
# 1                Buenos Aires                     La Matanza
# 2                     Córdoba                        Capital
# 3                     Mendoza                      Las Heras
# 4                Buenos Aires            Malvinas Argentinas
#
#   carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0           Buenos Aires                   NaN     2020-06-01  ...
# ...

# %%
df_caba = completo.loc[completo['residencia_provincia_nombre'] == 'CABA', :]
df_caba.fecha_apertura.sort_values().tail()
# Out:
# 2112277   2020-10-12
# 2112273   2020-10-12
# 2112272   2020-10-12
# 2112333   2020-10-12
# 2111694   2020-10-12
# Name: fecha_apertura, dtype: datetime64[ns]

# %%
df_caba = df_caba.loc[df_caba.fecha_apertura < pd.Timestamp(year=2020, month=9, day=30), :]
df_caba.fecha_apertura.sort_values().tail()
# Out:
# 1765141   2020-09-29
# 1765140   2020-09-29
# 1776697   2020-09-29
# 1765156   2020-09-29
# 1784656   2020-09-29
# Name: fecha_apertura, dtype: datetime64[ns]

# %%
df_caba = df_caba.drop('ultima_actualizacion', axis=1)

# %%
df_caba.reset_index().to_feather('./data/CovidCabaFeather')

# %%
df = pd.read_feather('./data/CovidCabaFeather')
df
# Out:
#           index  id_evento_caso sexo  edad edad_años_meses  \
# 0             0         1000000    M  53.0            Años
# 1             6         1000008    F  69.0            Años
# 2             8         1000010    M   7.0            Años
# 3            10         1000012    M  46.0            Años
# 4            13         1000015    F  29.0            Años
# ...         ...             ...  ...   ...             ...
# 357708  2264937          999976    F  27.0            Años
# 357709  2264941          999982    M  38.0            Años
# 357710  2264947          999990    F  50.0            Años
# 357711  2264952          999996    M  42.0            Años
# 357712  2264953          999997    F  30.0            Años
#
#        residencia_pais_nombre residencia_provincia_nombre  \
# 0                   Argentina                        CABA
# 1                   Argentina                        CABA
# 2                   Argentina                        CABA
# ...
